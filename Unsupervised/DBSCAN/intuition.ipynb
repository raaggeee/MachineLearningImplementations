# %% [markdown]
# ## DBSCAN - Densiry Based Spatial Clustering of Application with Noise

# %% [markdown]
# ## Concept of Epsilion and MinPts
# - Epsilion is the radius of the neighbour
# - MinPts is the minimum points which should be in epsilion neighbours.
